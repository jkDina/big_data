# %%
#Загрузить данные в pandas
#Для каждого атрибута вывести максимальное, минимальное и среднее значение
#Вывести матрицу корреляций между признаками
#Для каждого признака построить гистограмму его значений
#Построить классификатор для вин (целевая переменная - Cultivar)
#Оценить качество классификатора на отложенной (train_test_split) выборке

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
data = pd.read_csv('wine.csv')
data.head(n=10)
# Out:
#    Cultivar  Alcohol  ...  OD280/OD315 of diluted wines  Proline
# 0         1    14.23  ...                          3.92                 1065
# 1         1    13.20  ...                          3.40                 1050
# 2         1    13.16  ...                          3.17                 1185
# 3         1    14.37  ...                          3.45                 1480
# 4         1    13.24  ...                          2.93                  735
# 5         1    14.20  ...                          2.85                 1450
# 6         1    14.39  ...                          3.58                 1290
# 7         1    14.06  ...                          3.58                 1295
# 8         1    14.83  ...                          2.85                 1045
# 9         1    13.86  ...                          3.55                 1045
#
# [10 rows x 14 columns]

# %%
data.describe()
# Out:
#          Cultivar  ...  Proline
# count  178.000000  ...           178.000000
# mean     1.938202  ...           746.893258
# std      0.775035  ...           314.907474
# min      1.000000  ...           278.000000
# 25%      1.000000  ...           500.500000
# 50%      2.000000  ...           673.500000
# 75%      3.000000  ...           985.000000
# max      3.000000  ...          1680.000000
#
# [8 rows x 14 columns]

# %%
#максимальное значение
data.max(axis = 0, skipna = True)
# Out:
# Cultivar                           3.00
# Alcohol                           14.83
# Malic acid                         5.80
# Ash                                3.23
# Alcalinity of ash                 30.00
# Magnesium                        162.00
# Total phenols                      3.88
# Flavanoids                         5.08
# Nonflavanoid phenols               0.66
# Proanthocyanins                    3.58
# Color intensity                   13.00
# Hue                                1.71
# OD280/OD315 of diluted wines       4.00
# Proline                         1680.00
# dtype: float64

# %%
#минимальное значение
data.min(axis = 0, skipna = True)
# Out:
# Cultivar                          1.00
# Alcohol                          11.03
# Malic acid                        0.74
# Ash                               1.36
# Alcalinity of ash                10.60
# Magnesium                        70.00
# Total phenols                     0.98
# Flavanoids                        0.34
# Nonflavanoid phenols              0.13
# Proanthocyanins                   0.41
# Color intensity                   1.28
# Hue                               0.48
# OD280/OD315 of diluted wines      1.27
# Proline                         278.00
# dtype: float64

# %%
#среднее значение
data.mean(axis = 0, skipna = True)
# Out:
# Cultivar                          1.938202
# Alcohol                          13.000618
# Malic acid                        2.336348
# Ash                               2.366517
# Alcalinity of ash                19.494944
# Magnesium                        99.741573
# Total phenols                     2.295112
# Flavanoids                        2.029270
# Nonflavanoid phenols              0.361854
# Proanthocyanins                   1.590899
# Color intensity                   5.058090
# Hue                               0.957449
# OD280/OD315 of diluted wines      2.611685
# Proline                         746.893258
# dtype: float64

# %%
#Вывести матрицу корреляций между признаками
data.corr()
# Out:
#                               Cultivar  ...  Proline
# Cultivar                      1.000000  ...            -0.633717
# Alcohol                      -0.328222  ...             0.643720
# Malic acid                    0.437776  ...            -0.192011
# Ash                          -0.049643  ...             0.223626
# Alcalinity of ash             0.517859  ...            -0.440597
# Magnesium                    -0.209179  ...             0.393351
# Total phenols                -0.719163  ...             0.498115
# Flavanoids                   -0.847498  ...             0.494193
# Nonflavanoid phenols          0.489109  ...            -0.311385
# Proanthocyanins              -0.499130  ...             0.330417
# Color intensity               0.265668  ...             0.316100
# Hue                          -0.617369  ...             0.236183
# OD280/OD315 of diluted wines -0.788230  ...             0.312761
# Proline                      -0.633717  ...             1.000000
#
# ...

# %%
data.columns
# Out:
# Index(['Cultivar', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash  ',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue',
#        'OD280/OD315 of diluted wines', 'Proline            '],
#       dtype='object')

# %%
#Для каждого признака построить гистограмму его значений
for column in data.columns:
  fig, ax = plt.subplots()
  ax.hist(data[column])
  ax.set_title(column)

# %%
list(data.columns)
# Out:
# ['Cultivar',
#  'Alcohol',
#  'Malic acid',
#  'Ash',
#  'Alcalinity of ash  ',
#  'Magnesium',
#  'Total phenols',
#  'Flavanoids',
#  'Nonflavanoid phenols',
#  'Proanthocyanins',
#  'Color intensity',
#  'Hue',
#  'OD280/OD315 of diluted wines',
#  'Proline            ']

# %%
#Построить классификатор для вин (целевая переменная - Cultivar)
data = pd.read_csv('wine.csv')
target = data["Cultivar"]
del data['Cultivar']

X_train, X_test, y_train, y_test = train_test_split(data, target)

model = RandomForestClassifier(n_estimators=100, max_depth=20)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=20, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
#Оценить качество классификатора на отложенной (train_test_split) выборке
prediction = model.predict(X_test)
print('accuracy_score=', accuracy_score(prediction, y_test))
print('precision_score=', precision_score(prediction, y_test, average='weighted'))
print('recall_score=', recall_score(prediction, y_test, average='weighted'))
# Out:
# accuracy_score= 0.9777777777777777
# precision_score= 0.9790123456790124
# recall_score= 0.9777777777777777
